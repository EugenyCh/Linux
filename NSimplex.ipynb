# %%
import numpy as np
import json
from itertools import combinations

# %%
N = 10
scale = 2

# %%
vers = np.zeros((N + 1, N))

# %%
vers[0] = [1] + [0] * (N - 1)

# %%
for i in range(1, N + 1):
    vers[i][0]  = -1 / N

# %%
for g in range(1, N):
    vers[g][g] = np.sqrt(1 - np.multiply(vers[g], vers[g]))[0]
    m = -vers[g][g] / (N - 1)
    for i in range(g + 1, N + 1):
        vers[i][g] = m

# %%
X = [0] * N
for n in range(N):
    for m in range(N + 1):
        X[n] += vers[m][n]
    X[n] /= (N + 1)
X
# Out:
# [1.2616170734376778e-17,
#  -7.569702440626067e-18,
#  0.010050378152592113,
#  0.020100756305184233,
#  0.030151134457776355,
#  0.04020151261036848,
#  0.0502518907629606,
#  0.06030226891555272,
#  0.07035264706814484,
#  0.08040302522073696]

# %%
vers = [list((vers[m] - X) * scale) for m in range(len(vers))]
vers
# Out:
# [[2.0,
#   1.5139404881252134e-17,
#   -0.020100756305184226,
#   -0.040201512610368466,
#   -0.06030226891555271,
#   -0.08040302522073696,
#   -0.1005037815259212,
#   -0.12060453783110545,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   1.98997487421324,
#   -0.020100756305184226,
#   -0.040201512610368466,
#   -0.06030226891555271,
#   -0.08040302522073696,
#   -0.1005037815259212,
#   -0.12060453783110545,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   1.9698741179080557,
#   -0.040201512610368466,
#   -0.06030226891555271,
#   -0.08040302522073696,
#   -0.1005037815259212,
#   -0.12060453783110545,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   1.9497733616028714,
#   -0.06030226891555271,
#   -0.08040302522073696,
#   -0.1005037815259212,
#   -0.12060453783110545,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   -0.2613098319673951,
#   1.9296726052976871,
#   -0.08040302522073696,
#   -0.1005037815259212,
#   -0.12060453783110545,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   -0.2613098319673951,
#   -0.28141058827257937,
#   1.9095718489925029,
#   -0.1005037815259212,
#   -0.12060453783110545,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   -0.2613098319673951,
#   -0.28141058827257937,
#   -0.30151134457776363,
#   1.8894710926873188,
#   -0.12060453783110545,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   -0.2613098319673951,
#   -0.28141058827257937,
#   -0.30151134457776363,
#   -0.32161210088294784,
#   1.8693703363821346,
#   -0.14070529413628968,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   -0.2613098319673951,
#   -0.28141058827257937,
#   -0.30151134457776363,
#   -0.32161210088294784,
#   -0.3417128571881321,
#   1.8492695800769503,
#   -0.16080605044147392],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   -0.2613098319673951,
#   -0.28141058827257937,
#   -0.30151134457776363,
#   -0.32161210088294784,
#   -0.3417128571881321,
#   -0.3618136134933163,
#   1.829168823771766],
#  [-0.20000000000000004,
#   -0.22110831935702663,
#   -0.2412090756622109,
#   -0.2613098319673951,
#   -0.28141058827257937,
#   -0.30151134457776363,
#   -0.32161210088294784,
#   -0.3417128571881321,
#   -0.3618136134933163,
#   -0.3819143697985006]]

# %%
polygons = list(combinations(vers, 3))

# %%
len(polygons)
# Out:
# 165

# %%
data = {
    "Dimension": N,
    "Polygons": polygons
}

# %%
with open(str(N) + "Simplex.json", "w") as file:
    json.dump(data, file)
